# %% [markdown]
# # Skin Cancer Detection - Model Training Demo
#
# This notebook demonstrates how to train and evaluate skin cancer detection models using the provided training scripts.
#
# ## Table of Contents
# 1. [Setup and Configuration](#setup)
# 2. [Data Preparation](#data-prep)
# 3. [Model Training](#training)
# 4. [Model Evaluation](#evaluation)
# 5. [Results Analysis](#analysis)
