# %% [markdown]
# # 🔬 Skin Cancer Detection - Model Training
#
# This notebook will help you train multiple state-of-the-art models for skin cancer detection using the ISIC dataset.
#
# ## 🎯 What You'll Get:
# - **Multiple Models**: Custom CNN, ResNet50, EfficientNet, VGG16
# - **Professional Evaluation**: Confusion matrices, ROC curves, detailed metrics
# - **Model Comparison**: Side-by-side performance analysis
# - **Downloadable Models**: Ready to use in your Flask app
#
# ## 🚀 Getting Started:
# 1. **Runtime**: Go to Runtime → Change runtime type → GPU (T4 GPU)
# 2. **Run All**: Runtime → Run all (or use Ctrl+F9)
# 3. **Upload Dataset**: When prompted, upload your ISIC dataset
#
# ---
